# %%
import matplotlib.pyplot as plt    # import matplotlib
import numpy as np
# import pycircstat
import pickle as pkl
import scipy.io
import pandas as pd 

mat = scipy.io.loadmat('Part8NI1.mat')

print('contents of file regionsMap.mat  (matlab < v7.3):')
for key in mat:
    print(key, type(mat[key]))
 
np.shape(mat["channel"])

c = np.array(mat["channel"])
chdf = pd.DataFrame(c)
# besa_channels_all = mat['besa_channels_all']

# amp_array = np.array(besa_channels_all[0][0][-3])
# amp_df = pd.DataFrame(amp_array)

# amp_df
# Out:
# contents of file regionsMap.mat  (matlab < v7.3):
# __header__ <class 'bytes'>
# __version__ <class 'str'>
# __globals__ <class 'list'>
# channel <class 'numpy.ndarray'>

# %%
chdf

# for i in range(1):
#     plt.plot(amp_array[:,i])
# plt.show()

# plt
# Out:
#               0         1          2          3          4          5   \
# 0       0.701767  0.271409   0.117522  -0.853212   0.744721   0.694759
# 1      -0.701767 -0.271409  -0.117522   0.853212  -0.744721  -0.694759
# 2      -1.881663 -0.008679  -0.135073   3.453523  -3.173902  -1.274400
# 3      -2.805658  0.224670  -0.084533   5.875218  -5.583996  -0.934395
# 4      -3.826722 -0.543463  -0.063293   6.960398  -7.134874  -0.105905
# 5      -5.176323 -2.545910   0.016392   6.270020  -7.611880   0.664668
# 6      -6.376212 -4.984178   0.243484   4.499623  -7.340887   1.064948
# 7      -6.382331 -6.487472   0.498597   3.112750  -6.843000   1.258914
# 8      -4.401862 -6.103987   0.453102   3.372618  -6.444893   1.569168
# 9      -0.689626 -4.043472  -0.222172   5.428917  -6.128697   2.159721
# 10      3.354133 -1.535998  -1.468581   8.171243  -5.714074   2.802763
# 11      5.927797 -0.069482  -2.783169   9.976374  -5.159123   3.054958
# 12      6.054962 -0.269546  -3.399183   9.797812  -4.603981   2.689492
# 13      4.132861 -1.572416  -2.879296   7.921197  -4.147810   2.002488
# 14      1.599854 -2.694194  -1.403922   5.725554  -3.701109   1.666818
# 15     -0.271061 -2.741044   0.221125   4.723374  -3.131747   2.260125
# 16     -1.030231 -1.672771   1.156866   5.535286  -2.355253   3.787651
# 17     -1.151013 -0.391448   1.070837   7.499855  -1.711194   5.559423
# 18     -1.173791  0.162866   0.332515   9.225873  -1.634649   6.531241
# 19     -1.181230 -0.293522  -0.302382   9.611123  -2.357761   6.005030
# 20     -0.757405 -1.208647  -0.294712   8.613816  -3.482109   4.092607
# 21      0.315303 -1.810235   0.294676   7.203691  -4.175692   1.601633
# 22      1.610065 -1.653735   1.005905   6.568332  -3.653312  -0.411510
# 23      2.202493 -1.085097   1.417113   7.205666  -1.883940  -1.325757
# 24      1.542772 -0.637122   1.668776   8.480752   0.478010  -1.217738
# 25      0.016569 -0.602646   2.380832   9.084986   2.448413  -0.695172
# 26     -1.301628 -0.826508   4.163934   7.991758   3.403932  -0.468938
# 27     -1.580055 -0.883806   6.995756   5.239032   3.553594  -0.841453
# 28     -1.058514 -0.708916   9.959442   2.038868   3.554524  -1.548397
# 29     -0.940369 -0.788188  11.713223   0.001002   3.841990  -2.108798
# ...          ...       ...        ...        ...        ...        ...
# 77551   0.716501  5.634979  -0.079601  -5.500854   5.797252  14.906506
# 77552  -1.407566  4.348022  -0.670634  -6.398567   4.790236  14.878381
# 77553  -2.192928  0.985543  -1.372853  -6.541152   3.804396  13.674733
# 77554  -2.208812 -2.907453  -1.020073  -5.352775   3.413128  12.396051
# 77555  -2.447544 -5.408472   0.455447  -3.141074   3.382639  11.783167
# 77556  -3.351202 -5.318839   2.093397  -0.781253   2.900234  11.824386
# 77557  -4.550204 -2.771630   2.803993   1.034027   1.283914  12.024394
# 77558  -5.345179  0.951993   2.332784   2.281052  -1.301317  12.028175
# 77559  -5.571390  4.225801   1.475483   3.532024  -3.963945  11.874356
# 77560  -5.772785  5.950096   1.372936   5.424118  -5.768075  11.735435
# 77561  -6.701481  5.865898   2.414638   8.082096  -6.572324  11.491385
# 77562  -8.440547  4.502163   3.872880  11.005342  -7.082135  10.573387
# 77563 -10.062819  2.611689   4.534190  13.450109  -8.227132   8.333097
# 77564 -10.254596  0.879911   3.840638  14.993152 -10.244184   4.633658
# 77565  -8.425933 -0.465411   2.500945  15.775352 -12.524011  -0.010388
# 77566  -5.334712 -1.490031   2.004159  16.276039 -14.158401  -4.736872
# 77567  -2.563963 -2.328194   3.355606  16.787550 -14.739589  -8.960301
# 77568  -1.332581 -2.960013   6.118505  17.091150 -14.653596 -12.588017
# 77569  -1.466159 -3.248268   8.536354  16.585508 -14.674186 -15.877072
# 77570  -1.580693 -2.979561   8.824615  14.782565 -15.016020 -18.792990
# 77571  -0.305304 -2.178674   6.494015  11.753345 -15.109351 -20.814327
# 77572   2.388004 -1.318502   2.715325   8.232070 -14.096031 -21.256187
# 77573   5.019417 -1.109520  -0.535998   5.248546 -11.697451 -19.899031
# 77574   5.635258 -2.130073  -1.925047   3.556569  -8.721158 -17.373793
# 77575   3.333610 -4.418793  -1.627357   3.311131  -6.621945 -14.885239
# 77576  -0.804560 -7.207609  -0.944644   4.007359  -6.338779 -13.413368
# 77577  -4.472411 -9.384934  -1.155691   4.819876  -7.606912 -13.071452
# 77578  -5.519259 -9.955228  -2.461844   4.986995  -8.955550 -13.104074
# 77579  -3.485718 -8.767622  -3.991443   4.128275  -8.900114 -12.582984
# 77580   0.323135 -6.527939  -4.594025   2.326272  -6.956046 -11.141753
#
#               6         7         8         9          10        11        12  \
# 0       0.251464  0.138127  0.247101  0.615840   1.284990 -0.189390  0.710577
# 1      -0.251464 -0.138127 -0.247101 -0.615840  -1.284990  0.189390 -0.710577
# 2      -1.064597 -0.340187 -1.527631 -3.016391  -3.105418  0.281020 -0.056785
# 3      -1.701917 -0.585588 -2.922502 -5.154339  -3.460867 -0.018003  1.960850
# 4      -1.804622 -0.921750 -3.464775 -5.701535  -2.414333 -0.446499  3.551205
# 5      -1.460468 -1.199269 -2.653347 -4.413746  -0.737309 -0.555700  3.318274
# 6      -1.036299 -1.190292 -0.941739 -2.326902   0.475154 -0.068649  1.354213
# 7      -0.865882 -0.774320  0.540592 -1.031057   0.495536  0.815643 -0.870521
# 8      -0.947518 -0.087975  0.791607 -1.447153  -0.588473  1.498026 -1.801930
# 9      -0.973702  0.515738 -0.274148 -3.265704  -2.011964  1.449249 -1.171500
# 10     -0.671879  0.691776 -1.781423 -5.254735  -2.835596  0.668086 -0.142620
# 11     -0.050215  0.355237 -2.597363 -6.211364  -2.639441 -0.228372 -0.178437
# 12      0.579665 -0.213683 -2.221732 -5.716898  -1.775975 -0.406312 -1.503963
# 13      0.916327 -0.556829 -1.153476 -4.231481  -1.047842  0.513523 -2.765903
# 14      0.938166 -0.331259 -0.390573 -2.514166  -1.066072  2.115661 -2.103559
# 15      0.919368  0.421757 -0.553564 -1.094583  -1.767221  3.404478  1.095407
# 16      1.146358  1.295542 -1.341512 -0.122323  -2.520016  3.546350  5.403067
# 17      1.630471  1.761625 -1.845761  0.386621  -2.610735  2.446239  8.258668
# 18      2.093621  1.490952 -1.366036  0.265334  -1.894439  0.871592  7.891585
# 19      2.229824  0.535012 -0.072665 -0.655410  -0.906007 -0.129534  4.809277
# 20      1.996874 -0.732091  1.098871 -2.186061  -0.425642  0.085212  1.350036
# 21      1.624054 -1.874334  1.245637 -3.627707  -0.827746  1.387623 -0.138693
# 22      1.397693 -2.614013  0.244904 -4.041829  -1.775894  3.113034  0.903572
# 23      1.368372 -2.943541 -1.159685 -2.888117  -2.556977  4.617829  2.996160
# 24      1.395047 -3.017752 -1.991233 -0.489690  -2.752159  5.682786  4.046381
# 25      1.401773 -2.983188 -1.832413  2.175292  -2.654397  6.399453  3.230108
# 26      1.591977 -2.900651 -1.089459  4.051034  -3.070525  6.820219  1.608806
# 27      2.322010 -2.742641 -0.513435  4.664634  -4.508290  6.686582  1.023568
# 28      3.715287 -2.504231 -0.485179  4.165514  -6.683843  5.612899  2.390311
# 29      5.320813 -2.257671 -0.708464  2.985208  -8.532863  3.560338  4.738427
# ...          ...       ...       ...       ...        ...       ...       ...
# 77551  -3.601229  2.743822 -2.105014  2.246703   3.970443  2.604140  1.560785
# 77552  -4.845459  4.686224 -2.860016  3.590117   4.666173  1.682958  2.819017
# 77553  -5.503152  5.136147 -2.821470  5.235704   5.056310  0.472188  3.754261
# 77554  -5.327278  3.878212 -2.287388  6.402567   4.313860  0.104479  3.860534
# 77555  -4.722987  1.769596 -1.728660  6.052889   2.572872  0.985056  2.997194
# 77556  -4.310129  0.130697 -1.404536  3.733728   0.688487  2.462616  1.474753
# 77557  -4.380701 -0.163913 -1.217355  0.175186  -0.392923  3.289779 -0.021311
# 77558  -4.665049  0.753190 -0.912988 -2.993342  -0.344968  2.619401 -0.741953
# 77559  -4.583561  1.948140 -0.364013 -4.209972   0.366854  0.654446 -0.243155
# 77560  -3.832570  2.431051  0.242157 -2.884223   0.983350 -1.464611  1.405675
# 77561  -2.717511  1.865121  0.575113  0.156924   1.040721 -2.501979  3.603403
# 77562  -1.938177  0.672051  0.409963  3.268642   0.633197 -1.967938  5.459537
# 77563  -2.023337 -0.465289 -0.173324  4.940734   0.109555 -0.384805  6.316493
# 77564  -2.783476 -1.239241 -0.793598  4.566792  -0.429077  1.206760  5.975881
# 77565  -3.333402 -1.954193 -1.006548  2.548186  -1.329813  2.032710  4.758001
# 77566  -2.645634 -3.116672 -0.538441 -0.094422  -3.175140  2.021387  3.225569
# 77567  -0.356672 -4.799611  0.535995 -2.371041  -6.025331  1.616009  1.880298
# 77568   2.873963 -6.365335  1.827384 -3.723960  -9.127976  1.225034  0.931638
# 77569   5.682501 -6.814445  2.807162 -4.039108 -11.075127  0.758861  0.394513
# 77570   6.854303 -5.545459  3.030442 -3.556818 -10.654835 -0.211087  0.195573
# 77571   6.134867 -2.905440  2.366684 -2.579255  -7.738061 -1.987203  0.325282
# 77572   4.441887 -0.122063  1.070261 -1.376813  -3.650601 -4.284686  0.813551
# 77573   3.279449  1.443472 -0.313541 -0.118941  -0.530014 -6.284591  1.609373
# 77574   3.786218  1.108150 -1.219545  0.992279  -0.209563 -7.080137  2.492623
# 77575   5.969590 -0.755558 -1.383543  1.773690  -3.050860 -6.353737  3.157398
# 77576   8.693018 -3.013408 -0.976306  2.007016  -7.604631 -4.545840  3.336278
# 77577  10.376669 -4.501768 -0.488780  1.457832 -11.409387 -2.590897  2.948607
# 77578   9.961151 -4.637113 -0.366095  0.081572 -12.314837 -1.282476  2.130103
# 77579   7.513752 -3.607514 -0.739472 -1.890086  -9.741308 -0.819592  1.128034
# 77580   4.116518 -2.057377 -1.319787 -3.928506  -4.888879 -0.830067  0.154809
#
#               13        14
# 0      -0.474359  1.687512
# 1       0.474359 -1.687512
# 2       2.029306 -4.394711
# 3       3.412295 -5.228116
# 4       3.819981 -4.194921
# 5       3.090092 -2.398296
# 6       1.824789 -1.222710
# 7       0.961024 -1.412847
# 8       0.868960 -2.577298
# 9       1.013126 -3.704330
# 10      0.357693 -3.980997
# 11     -1.594934 -3.487513
# 12     -4.100550 -2.921906
# 13     -5.505537 -2.903271
# 14     -4.466560 -3.283339
# 15     -1.153901 -3.235936
# 16      2.683181 -1.957884
# 17      4.786547  0.537829
# 18      4.073975  3.244730
# 19      1.449052  4.800056
# 20     -0.934838  4.506717
# 21     -1.307982  2.858394
# 22      0.462331  1.227156
# 23      2.915839  0.830238
# 24      4.377073  1.932771
# 25      4.385464  3.713941
# 26      3.926447  4.988805
# 27      4.403804  5.096487
# 28      6.220162  4.282157
# 29      8.257973  3.306223
# ...          ...       ...
# 77551   3.126933 -0.993642
# 77552   2.882673 -2.435970
# 77553   3.515730 -3.723415
# 77554   4.868660 -4.028920
# 77555   5.907446 -3.388376
# 77556   5.726193 -2.671313
# 77557   4.482946 -2.712173
# 77558   3.417784 -3.502363
# 77559   3.990460 -4.252189
# 77560   6.646530 -4.093282
# 77561  10.254698 -2.968161
# 77562  12.852715 -1.765801
# 77563  13.001145 -1.603314
# 77564  10.753120 -2.811545
# 77565   7.482986 -4.535223
# 77566   4.836207 -5.369158
# 77567   3.532639 -4.406901
# 77568   3.064205 -2.004663
# 77569   2.327575  0.497483
# 77570   0.663150  1.825749
# 77571  -1.610255  1.630810
# 77572  -3.514316  0.547574
# 77573  -4.238812 -0.522942
# 77574  -3.816427 -1.183097
# 77575  -3.013341 -1.825114
# 77576  -2.786716 -2.878056
# 77577  -3.608548 -4.208013
# 77578  -5.182941 -4.893795
# 77579  -6.804519 -3.974928
# 77580  -7.865339 -1.215303
#
# [77581 rows x 15 columns]

# %%
from scipy.signal import butter, lfilter

def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def butter_bandpass_filter(data, lowcut, highcut, fs, order=1):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

def filter_session(data,lowcut,highcut,fs,order=1):
    channels = np.shape(data)[1]
    filtered = np.zeros(np.shape(data))
    for channel in range(channels):
        filt_chan = butter_bandpass_filter(c[:,channel], lowcut, highcut, fs, order=order)
        filtered[:,channel] = filt_chan
    return filtered

# %%
fs = 250.0
lowcut = 4.0
highcut = 8.0
T = 1/fs
t = np.arange(0,np.shape(c)[0])/200
fig, axes = plt.subplots(nrows=2, figsize=(20,30))
alpha = np.zeros(np.shape(c))
for channel in range(15):
    filtered = butter_bandpass_filter(c[:,channel], lowcut, highcut, fs, order=1)
    alpha[:,channel] = filtered
    t_range = range(500,1000)
    data = c[t_range,channel]
    data_min = np.min(data)
    data_max = np.max(data)
    data_scale = data_max-data_min
    axes[0].plot(t[t_range],data/data_scale+channel,'b')
    #y = butter_bandpass_filter(data, lowcut, highcut, fs, order=1)
    axes[1].plot(t_range,filtered[t_range]/data_scale+channel,'k')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import freqz

# Sample rate and desired cutoff frequencies (in Hz).
fs = 5000.0
lowcut = 500.0
highcut = 1250.0

# Plot the frequency response for a few different orders.
plt.figure(1)
plt.clf()
for order in [3, 6, 9]:
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    w, h = freqz(b, a, worN=2000)
    plt.plot((fs * 0.5 / np.pi) * w, abs(h), label="order = %d" % order)

plt.plot([0, 0.5 * fs], [np.sqrt(0.5), np.sqrt(0.5)],
         '--', label='sqrt(0.5)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Gain')
plt.grid(True)
plt.legend(loc='best')

# Filter a noisy signal.
T = 0.05
nsamples = T * fs
t = np.linspace(0, T, nsamples, endpoint=False)
a = 0.02
f0 = 600.0
x = 0.1 * np.sin(2 * np.pi * 1.2 * np.sqrt(t))
x += 0.01 * np.cos(2 * np.pi * 312 * t + 0.1)
x += a * np.cos(2 * np.pi * f0 * t + .11)
x += 0.03 * np.cos(2 * np.pi * 2000 * t)
plt.figure(2)
plt.clf()
plt.plot(t, x, label='Noisy signal')

y = butter_bandpass_filter(x, lowcut, highcut, fs, order=6)
plt.plot(t, y, label='Filtered signal (%g Hz)' % f0)
plt.xlabel('time (seconds)')
plt.hlines([-a, a], 0, T, linestyles='--')
plt.grid(True)
plt.axis('tight')
plt.legend(loc='upper left')

plt.show()

# %%
bands_amplitude = np.zeros((15, 15,4))
band_list = [(4,8),(8,12),(12,40),(40,50)]
for band_idx, band_pass in enumerate(band_list):  
    
    collection = np.zeros((15, 15))

    filtered = filter_session(c,band_pass[0],band_pass[1],250)

    hilbert_filtered = signal.hilbert(filtered,axis=0)

    amplitude_filtered = np.abs(hilbert_filtered)

    corr_filtered_amp = np.corrcoef(amplitude_filtered,rowvar=False)
    
    bands_amplitude[:,:,band_idx] = corr_filtered_amp

# %%
band = ['theta','alpha','beta','gamma']
for i in range(4):
   
    plt.imshow(bands_amplitude[:,:,i])
    print(np.shape(bands_amplitude))
    #print(bands_amplitude[:,:,i])
    f = plt.figure(figsize=(18, 12))
    file_name = 'amplitude'+str(band[i])+'.pdf'
    f.savefig(file_name, bbox_inches='tight')
    plt.show()
# Out:
# (15, 15, 4)
# (15, 15, 4)
# (15, 15, 4)
# (15, 15, 4)

# %%
functional_amplitude = np.zeros((np.shape(bands_amplitude)))
band = ['theta','alpha','beta','gamma']
for idx in range(4):
    v = np.sort(np.unique(bands_amplitude[:,:,idx]))
    i = int(np.shape(v)[0]*0.8)
    functional_amplitude[:,:,idx] = bands_amplitude[:,:,idx] >  v[i]
    f = plt.figure(figsize=(18, 12))
    file_name = 'binary_amplitude' + str(band[idx]) + '.pdf'
    
    plt.imshow(functional_amplitude[:,:,idx])
    f.savefig(file_name, bbox_inches='tight')
    plt.show()

# %%
def phasecorr(ang):

    a = np.zeros(len(ang))
    b = np.zeros(len(ang))
    c = np.zeros(len(ang))
    #mu = sp.stats.circmean(ang)

    nc = len(ang[1]) # length of channels

    r = np.zeros((nc,nc))

    for j in range(nc):
        for k in range(nc):
            mu_j = scipy.stats.circmean(ang[:,j])
            mu_k = scipy.stats.circmean(ang[:,k])
            a = np.sin(ang[:,j]-mu_j)*np.sin(ang[:,k]-mu_j)
            b = (np.sin(ang[:,j]-mu_j))**2
            c = (np.sin(ang[:,k]-mu_j))**2
            r[j,k] = np.sum(a)/np.sqrt(np.sum(b)*np.sum(c))
    return r

# %%
bands_phase = np.zeros((15, 15,4))
band_list = [(4,8),(8,12),(12,40),(40,50)]
for band_idx, band_pass in enumerate(band_list):  
    
    collection = np.zeros((15, 15))

    filtered = filter_session(c,band_pass[0],band_pass[1],250)

    hilbert_filtered = signal.hilbert(filtered,axis=0)

    phase_filtered = np.angle(hilbert_filtered)

    corr_filtered_phase = phasecorr(phase_filtered)
        
    bands_phase[:,:,band_idx] = corr_filtered_phase

# %%
functional_phase = np.zeros((np.shape(bands_phase)))
band = ['theta','alpha','beta','gamma']
for idx in range(4):
    v = np.sort(np.unique(bands_phase[:,:,idx]))
    i = int(np.shape(v)[0]*0.8)
    functional_phase[:,:,idx] = bands_phase[:,:,idx] >  v[i]
    f = plt.figure(figsize=(18, 12))
    file_name = 'binary_phase' + str(band[idx]) + '.pdf'
    
    plt.imshow(functional_phase[:,:,idx])
    f.savefig(file_name, bbox_inches='tight')
    plt.show()

# %%
degree_amplitude = np.zeros((15,4))
for i in range(4):
    b = bands_amplitude[:,:,i]
    s = np.sum(b,axis=0)
    degree_amplitude[:,i] = s
np.shape(degree_amplitude)
plt.plot(degree_amplitude[:,0],degree_amplitude[:,1],'ko')
plt.show()
plt.plot(degree_amplitude[:,0],degree_amplitude[:,2],'ko')
plt.show()

# %%
degree_phases = np.zeros((15,4))
for i in range(4):
    b = bands_phase[:,:,i]
    s = np.sum(b,axis=0)
    degree_phases[:,i] = s
np.shape(degree_phases)
plt.plot(degree_phases[:,0],degree_phases[:,1],'ko')
plt.show()
plt.plot(degree_phases[:,0],degree_phases[:,2],'ko')
plt.show()

# %%
for i in range(4):
    plt.plot(degree_amplitude[:,i],degree_phases[:,i],'ko')
    plt.show()

# %%
from scipy import stats

font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 25}


for a in range(4):
    for p in range(4):
        f = plt.figure(figsize=(9, 6))
        file_name = 'degree corr' + str(band[a]) + str(band[p])+ '.pdf'
        plt.scatter(degree_amplitude[:,a],degree_phases[:,p],100,'k')
        plt.rc('font', **font)
        plt.xlabel('amplitude ' + str(band[a]),fontsize=12)
        plt.ylabel('phase ' + str(band[p]),fontsize=12)
        slope, intercept, r_value, p_value, std_err = stats.linregress(degree_amplitude[:,a],degree_phases[:,p])
        x = np.arange(np.min(degree_amplitude[:,a]),np.max(degree_amplitude[:,a]),1)
        y = intercept + slope*x
        plt.plot(x,y,'r-',lw=4)
        plt.text(x=np.min(degree_amplitude[:,a])+1,y=25,s='r='+np.str(round(np.corrcoef(degree_amplitude[:,a],degree_phases[:,p])[1,0],2)))
        plt.show()
        f.savefig(file_name, bbox_inches='tight')
# Out:
# /Users/nkhaja/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
